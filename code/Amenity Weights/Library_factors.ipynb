# %%
import warnings
import keplergl
import numpy as np
import osmnx as ox
import pandas as pd
import geopandas as gpd
from sklearn import preprocessing
import plotly.express as px
from skgstat import Variogram
import matplotlib.pyplot as plt
from shapely.geometry import Point
from pykrige.ok import OrdinaryKriging
from scipy.interpolate import NearestNDInterpolator
from tobler.area_weighted import area_interpolate
import plotly.express as px
import json
import ogr
import ipywidgets as widgets
from IPython.display import display

# %%
amen1 = pd.read_csv('vancouver_facilities_2.csv')
amen1.head()
# Out:
#    id          lat           lon                       type  \
# 0  10   49.1763542   -123.112783                     museum
# 1  15    49.261938   -123.151123                     museum
# 2  24    49.278786   -123.098796                     museum
# 3  41   49.2210003  -123.0091848                     artist
# 4  97  49.14709735  -122.6467963  heritage or historic site
#
#                                                 name       city  city_id
# 0                        12 Service Battalion Museum   Richmond  5915015
# 1  15th Field Artillery Regiment Museum And Archives  Vancouver  5915022
# 2                             221A Artist Run Centre  Vancouver  5915022
# 3                                 7302754 Canada Inc    Burnaby  5915025
# 4              Abc Heritage Preschool And Child Care    Langley  5915001

# %%
amen = pd.read_csv('vancouver_facilities.csv')
amen.head()
# Out:
#    Index                                      Facility_Name  \
# 0     10                        12 Service Battalion Museum
# 1     15  15th Field Artillery Regiment Museum And Archives
# 2     24                             221A Artist Run Centre
# 3     41                                 7302754 Canada Inc
# 4     97              Abc Heritage Preschool And Child Care
#
#                                 Source_Facility_Type  \
# 0                            military museum or fort
# 1                                     museum/gallery
# 2                                     museum/gallery
# 3  artist making fine art and exhibiting in galle...
# 4                   preschool and out of school care
#
#          ODCAF_Facility_Type                      Provider Unit Street_No  \
# 0                     museum  canadian museums association   ..      5500
# 1                     museum                     vancouver   ..      2025
# 2                     museum                     vancouver   ..       221
# 3                     artist                       burnaby   ..      6909
# 4  heritage or historic site           township of langley   ..      7949
#
#     Street_Name Postal_Code                 City Prov_Terr  \
# 0       no 4 rd     V6X 3L5             richmond        bc
# 1     11th av w     V6J 2C7            vancouver        bc
# 2  georgia st e     V6A 1Z6            vancouver        bc
# 3      mckay av          ..              burnaby        bc
# 4        208 st          ..  township of langley        bc
#
#                                Source_Format_Address   CSD_Name   CSDUID  \
# 0  5500 no. 4 rd the sherman armoury richmond bri...   Richmond  5915015
# 1                2025 w 11th av vancouver bc v6j 2c7  Vancouver  5915022
# 2              221 e georgia st vancouver bc v6a 1z6  Vancouver  5915022
# 3                                      6909 mckay av    Burnaby  5915025
# 4                                                 ..    Langley  5915001
#
#    PRUID     Latitude     Longitude
# 0     59   49.1763542   -123.112783
# 1     59    49.261938   -123.151123
# 2     59    49.278786   -123.098796
# 3     59   49.2210003  -123.0091848
# 4     59  49.14709735  -122.6467963

# %%
amen = amen[['Index', 'Latitude', 'Longitude', 'ODCAF_Facility_Type', 'Facility_Name', 'City', 'Postal_Code']]
amen.head()
# Out:
#    Index     Latitude     Longitude        ODCAF_Facility_Type  \
# 0     10   49.1763542   -123.112783                     museum
# 1     15    49.261938   -123.151123                     museum
# 2     24    49.278786   -123.098796                     museum
# 3     41   49.2210003  -123.0091848                     artist
# 4     97  49.14709735  -122.6467963  heritage or historic site
#
#                                        Facility_Name                 City  \
# 0                        12 Service Battalion Museum             richmond
# 1  15th Field Artillery Regiment Museum And Archives            vancouver
# 2                             221A Artist Run Centre            vancouver
# 3                                 7302754 Canada Inc              burnaby
# 4              Abc Heritage Preschool And Child Care  township of langley
#
#   Postal_Code
# 0     V6X 3L5
# 1     V6J 2C7
# 2     V6A 1Z6
# 3          ..
# 4          ..

# %%
library = amen[amen['ODCAF_Facility_Type'] == 'library or archives']
library.head()
# Out:
#     Index    Latitude     Longitude  ODCAF_Facility_Type  \
# 6     140   49.243554   -121.992562  library or archives
# 9     215   49.055541   -122.481863  library or archives
# 16    358  49.2476604  -123.1545938  library or archives
# 44    744    52.37201   -126.757864  library or archives
# 45   1749    52.41529   -121.847499  library or archives
#
#                                         Facility_Name             City  \
# 6                                     Agassiz Library  north vancouver
# 9                                  Aldergrove Library        vancouver
# 16  Archives of Anglican Provincial Synod of Briti...        vancouver
# 44                                 Bella Coola Branch          burnaby
# 45                                           Big Lake        vancouver
#
#    Postal_Code
# 6      V0M 1A0
# 9      V4W 3B8
# 16     V6H 2E2
# 44     V0T 1C0
# 45     V0L 1G0

# %%
library[["Latitude", "Longitude"]] = library[["Latitude", "Longitude"]].apply(pd.to_numeric, errors='coerce')
library = library.dropna()
library = library.reset_index(drop=True)

# %%
# lat and lon need to be numeric for joining

library = library.reset_index(drop=True)
library["Latitude"] = pd.to_numeric(library["Latitude"])
library["Longitude"] = pd.to_numeric(library["Longitude"])

# %%
lib_bc = pd.read_csv('public-library-branch-data.csv')
lib_bc.head()
# Out:
#                       LIBRARY_SYSTEM                             LOCATION  \
# 0  Alert Bay Public Library & Museum    Alert Bay Public Library & Museum
# 1       Beaver Valley Public Library         Beaver Valley Public Library
# 2        Bowen Island Public Library          Bowen Island Public Library
# 3             Burnaby Public Library         Bob Prittie Metrotown Branch
# 4             Burnaby Public Library  Cameron Library & Recreation Centre
#
#   BRANCH_UNIQUE_ID  SCHOOL_DISTRICT_SERVED           PHONE  \
# 0          BABM001                    85.0  (250) 974-5721
# 1          BFBV001                    20.0  (250) 367-7114
# 2           BBI001                    45.0  (604) 947-9788
# 3            BB001                    41.0  (604) 436-5427
# 4            BB002                    41.0  (604) 421-5454
#
#          PHYSICAL_ADDRESS          CITY PROVINCE POSTAL_CODE   LATITUDE  ...  \
# 0          116 Fir Street     Alert Bay       BC     V0N 1A0  50.584823  ...
# 1       1847 - 1st Street     Fruitvale       BC     V0G 1L0  49.112966  ...
# 2  430 Bowen Island Trunk  Bowen Island       BC     V0N 1G0  49.379906  ...
# 3  6100 Willingdon Avenue       Burnaby       BC     V5H 4N5  49.228301  ...
# 4     9523 Cameron Street       Burnaby       BC     V3J 1L6  49.253814  ...
#
#    LIBRARIAN_HRS_B� LIB_TECH_HRS_B� COMM_LIB_HRS_B� OTH_HRS_B�  \
# 0                 0               0             622        281
# 1                 0               0            4940       1350
# 2              1820               0               0       4107
# 3            42,224           1,733             NaN    104,199
# 4             6,834             NaN             NaN     16,311
#
#   branch_copiers� LEED_CERT_B� SHRD_FAC�  FLOORSPACE� HRS_OPEN� DAYS_OPEN�
# 0             1.0          NaN       NaN       213.36       618      191.0
# 1             1.0           No        No          270      2320      321.0
# 2             1.0           No       Yes          407      1953      303.0
# 3             4.0           No        No     5,673.00     3,612      339.0
# 4             1.0           No       Yes          465     2,901      341.0
#
# [5 rows x 38 columns]

# %%
van_list = ['Richmond','Vancouver','Burnaby','Township of Langley','North Vancouver','New Westminster','Maple Ridge','Port Moody','Surrey','Langley',
            'Coquitlam','Delta','Fort Langley','White Rock','Pitt Meadows','Port Coquitlam', 'West Vancouver']

# %%
lib_van = lib_bc[lib_bc['CITY'].isin(van_list)]
lib_van.count()
# Out:
# LIBRARY_SYSTEM            66
# LOCATION                  66
# BRANCH_UNIQUE_ID          66
# SCHOOL_DISTRICT_SERVED    66
# PHONE                     65
# PHYSICAL_ADDRESS          66
# CITY                      66
# PROVINCE                  66
# POSTAL_CODE               66
# LATITUDE                  66
# LONGITUDE                 66
# MTLS_OUTLET               66
# MTLS_CIRC_B               66
# CIRC_CHILD_MTLS_B         66
# REF_TRANS_B               65
# VISITS_B                  65
# AD_INLIB_PGMS_B�          65
# AD_OUT_PGMS_B�            63
# ADULT_ATTEND_B�           65
# CH_INLIB_PGMS_B�          65
# CH_OUT_PGMS_B�            65
# CHILD_ATTEND_B�           65
# YA_INLIB_PGMS_B�          65
# YA_OUT_PGMS_B�            64
# YA_ATTEND_B�              65
# ESL_INLIB_PGMS_B�         58
# ESL_OUT_PGMS_B�           56
# ESL_ATTEND_B�             58
# LIBRARIAN_HRS_B�          63
# LIB_TECH_HRS_B�           59
# COMM_LIB_HRS_B�           51
# OTH_HRS_B�                65
# branch_copiers�           66
# LEED_CERT_B�              64
# SHRD_FAC�                 64
# FLOORSPACE�               66
# HRS_OPEN�                 66
# DAYS_OPEN�                66
# dtype: int64

# %%
lib_van = lib_van[['BRANCH_UNIQUE_ID', 'POSTAL_CODE', 'LATITUDE', 'LONGITUDE', 'MTLS_OUTLET', 'VISITS_B', 'FLOORSPACE�', 'HRS_OPEN�', 'DAYS_OPEN�']]
lib_van.head()
# Out:
#    BRANCH_UNIQUE_ID POSTAL_CODE   LATITUDE   LONGITUDE MTLS_OUTLET VISITS_B  \
# 3             BB001     V5H 4N5  49.228301 -123.006342     373,232  749,695
# 4             BB002     V3J 1L6  49.253814 -122.898601      59,958  247,701
# 5             BB003     V5C 2G6  49.282696 -123.000713     163,916  440,899
# 6             BB004     V5E 1G8  49.218722 -122.952371      90,645  387,327
# 25          BCOQ001     V3B 0Y1  49.281096 -122.792675      85,271  572,820
#
#    FLOORSPACE� HRS_OPEN�  DAYS_OPEN�
# 3     5,673.00     3,612       339.0
# 4          465     2,901       341.0
# 5     1,860.00     3,329       341.0
# 6     1,627.50     3,329       341.0
# 25    3,205.00     3,630       357.0

# %%
lib_van = lib_van.reset_index(drop=True)

# %%
lib_van.columns = ['Branch_Id', 'Postal_Code', 'Latitude', 'Longitude', 'Total_Volumes', 'Annual_Visitors', 'Total_Space', 'Hrs_per_Year', 'Days_per_Year']
lib_van.head()
# Out:
#   Branch_Id Postal_Code   Latitude   Longitude Total_Volumes Annual_Visitors  \
# 0     BB001     V5H 4N5  49.228301 -123.006342       373,232         749,695
# 1     BB002     V3J 1L6  49.253814 -122.898601        59,958         247,701
# 2     BB003     V5C 2G6  49.282696 -123.000713       163,916         440,899
# 3     BB004     V5E 1G8  49.218722 -122.952371        90,645         387,327
# 4   BCOQ001     V3B 0Y1  49.281096 -122.792675        85,271         572,820
#
#   Total_Space Hrs_per_Year  Days_per_Year
# 0    5,673.00        3,612          339.0
# 1         465        2,901          341.0
# 2    1,860.00        3,329          341.0
# 3    1,627.50        3,329          341.0
# 4    3,205.00        3,630          357.0

# %%
df = library.merge(lib_van, on='Postal_Code', how='left')
df.count()
# Out:
# Index                  92
# Latitude_x             92
# Longitude_x            92
# ODCAF_Facility_Type    92
# Facility_Name_x        92
# City                   92
# Postal_Code            92
# Branch_Id              10
# Facility_Name_y        10
# Latitude_y             10
# Longitude_y            10
# Total_Volumes          10
# Annual_Visitors        10
# Total_Space            10
# Hrs_per_Year           10
# Days_per_Year          10
# dtype: int64

# %%
df = library.merge(lib_van, on='Facility_Name', how='left')
df.count()
# Out:
# Index                  93
# Latitude               93
# Longitude              93
# ODCAF_Facility_Type    93
# Facility_Name          93
# City                   93
# Postal_Code_x          93
# Branch_Id               6
# Postal_Code_y           6
# Total_Volumes           6
# Annual_Visitors         6
# Total_Space             6
# Hrs_per_Year            6
# Days_per_Year           6
# dtype: int64

# %%
library.Latitude = library.Latitude.round(2)
library.Longitude = library.Longitude.round(2)

lib_van.Latitude = lib_van.Latitude.round(2)
lib_van.Longitude = lib_van.Longitude.round(2)

# %%
df = library.merge(lib_van, on=['Latitude','Longitude'], how='left')
df.count()
# Out:
# Index                  95
# Latitude               95
# Longitude              95
# ODCAF_Facility_Type    95
# Facility_Name          95
# City                   95
# Postal_Code_x          95
# Branch_Id              42
# Postal_Code_y          42
# Total_Volumes          42
# Annual_Visitors        42
# Total_Space            42
# Hrs_per_Year           42
# Days_per_Year          42
# dtype: int64

# %%
df = df.dropna()
df.head()
# Out:
#     Index  Latitude  Longitude  ODCAF_Facility_Type  \
# 5    1840     49.23    -123.01  library or archives
# 7    1936     49.28    -123.07  library or archives
# 9    1964     49.08    -122.67  library or archives
# 11   2090     49.25    -122.90  library or archives
# 12   2093     49.25    -122.90  library or archives
#
#                     Facility_Name       City Postal_Code_x Branch_Id  \
# 5   Bob Prittie Metrotown Library    burnaby            ..     BB001
# 7                       Britannia  vancouver            ..    BVA001
# 9              Brookswood Library    langley            ..   BABF005
# 11                        Cameron  coquitlam       V3J 1L6     BB002
# 12                Cameron Library    burnaby            ..     BB002
#
#    Postal_Code_y Total_Volumes Annual_Visitors Total_Space Hrs_per_Year  \
# 5        V5H 4N5       373,232         749,695    5,673.00        3,612
# 7        V5L 4X4         7,942          14,446         118        1,030
# 9        V3A 2W2        25,669          90,898         372        2,885
# 11       V3J 1L6        59,958         247,701         465        2,901
# 12       V3J 1L6        59,958         247,701         465        2,901
#
#     Days_per_Year
# 5           339.0
# 7           206.0
# 9           301.0
# 11          341.0
# 12          341.0

# %%
df = df.drop('Postal_Code_x', 1)

# %%
df = df.replace(',','', regex=True)
df.head()
# Out:
#     Index  Latitude  Longitude  ODCAF_Facility_Type  \
# 5    1840     49.23    -123.01  library or archives
# 7    1936     49.28    -123.07  library or archives
# 9    1964     49.08    -122.67  library or archives
# 11   2090     49.25    -122.90  library or archives
# 12   2093     49.25    -122.90  library or archives
#
#                     Facility_Name       City Branch_Id Postal_Code_y  \
# 5   Bob Prittie Metrotown Library    burnaby     BB001       V5H 4N5
# 7                       Britannia  vancouver    BVA001       V5L 4X4
# 9              Brookswood Library    langley   BABF005       V3A 2W2
# 11                        Cameron  coquitlam     BB002       V3J 1L6
# 12                Cameron Library    burnaby     BB002       V3J 1L6
#
#    Total_Volumes Annual_Visitors Total_Space Hrs_per_Year  Days_per_Year
# 5         373232          749695     5673.00         3612          339.0
# 7           7942           14446         118         1030          206.0
# 9          25669           90898         372         2885          301.0
# 11         59958          247701         465         2901          341.0
# 12         59958          247701         465         2901          341.0

# %%
df[["Total_Volumes", "Annual_Visitors", "Total_Space"]] = df[["Total_Volumes", "Annual_Visitors", "Total_Space"]].apply(pd.to_numeric, errors='coerce')
df = df.reset_index(drop=True)
df.head()
# Out:
#    Index  Latitude  Longitude  ODCAF_Facility_Type  \
# 0   1840     49.23    -123.01  library or archives
# 1   1936     49.28    -123.07  library or archives
# 2   1964     49.08    -122.67  library or archives
# 3   2090     49.25    -122.90  library or archives
# 4   2093     49.25    -122.90  library or archives
#
#                    Facility_Name       City Branch_Id Postal_Code_y  \
# 0  Bob Prittie Metrotown Library    burnaby     BB001       V5H 4N5
# 1                      Britannia  vancouver    BVA001       V5L 4X4
# 2             Brookswood Library    langley   BABF005       V3A 2W2
# 3                        Cameron  coquitlam     BB002       V3J 1L6
# 4                Cameron Library    burnaby     BB002       V3J 1L6
#
#    Total_Volumes  Annual_Visitors  Total_Space Hrs_per_Year  Days_per_Year
# 0         373232           749695       5673.0         3612          339.0
# 1           7942            14446        118.0         1030          206.0
# 2          25669            90898        372.0         2885          301.0
# 3          59958           247701        465.0         2901          341.0
# 4          59958           247701        465.0         2901          341.0

# %% [markdown]
# ### Normalize Total_Volumes, Annual_Visitors, Total_Space

# %%
cols_to_norm = ['Total_Volumes','Annual_Visitors', 'Total_Space']
df[cols_to_norm] = df[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
df.head()
# Out:
#    Index  Latitude  Longitude  ODCAF_Facility_Type  \
# 0   1840     49.23    -123.01  library or archives
# 1   1936     49.28    -123.07  library or archives
# 2   1964     49.08    -122.67  library or archives
# 3   2090     49.25    -122.90  library or archives
# 4   2093     49.25    -122.90  library or archives
#
#                    Facility_Name       City Branch_Id Postal_Code_y  \
# 0  Bob Prittie Metrotown Library    burnaby     BB001       V5H 4N5
# 1                      Britannia  vancouver    BVA001       V5L 4X4
# 2             Brookswood Library    langley   BABF005       V3A 2W2
# 3                        Cameron  coquitlam     BB002       V3J 1L6
# 4                Cameron Library    burnaby     BB002       V3J 1L6
#
#    Total_Volumes  Annual_Visitors  Total_Space Hrs_per_Year  Days_per_Year
# 0       0.313325         0.387315     0.156200         3612          339.0
# 1       0.004510         0.006401     0.002925         1030          206.0
# 2       0.019497         0.046009     0.009933         2885          301.0
# 3       0.048484         0.127244     0.012499         2901          341.0
# 4       0.048484         0.127244     0.012499         2901          341.0

# %%
# using sklearn
x = df.values 
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled, columns=df.columns)

# %% [markdown]
# #### Average 3 values and obtain objective scores

# %%
lib_wt = df.copy()
lib_wt['Weight'] = lib_wt[['Total_Volumes','Annual_Visitors', 'Total_Space']].mean(axis=1)
lib_wt.head()
# Out:
#    Index  Latitude  Longitude  ODCAF_Facility_Type  \
# 0   1840     49.23    -123.01  library or archives
# 1   1936     49.28    -123.07  library or archives
# 2   1964     49.08    -122.67  library or archives
# 3   2090     49.25    -122.90  library or archives
# 4   2093     49.25    -122.90  library or archives
#
#                    Facility_Name       City Branch_Id Postal_Code_y  \
# 0  Bob Prittie Metrotown Library    burnaby     BB001       V5H 4N5
# 1                      Britannia  vancouver    BVA001       V5L 4X4
# 2             Brookswood Library    langley   BABF005       V3A 2W2
# 3                        Cameron  coquitlam     BB002       V3J 1L6
# 4                Cameron Library    burnaby     BB002       V3J 1L6
#
#    Total_Volumes  Annual_Visitors  Total_Space Hrs_per_Year  Days_per_Year  \
# 0       0.313325         0.387315     0.156200         3612          339.0
# 1       0.004510         0.006401     0.002925         1030          206.0
# 2       0.019497         0.046009     0.009933         2885          301.0
# 3       0.048484         0.127244     0.012499         2901          341.0
# 4       0.048484         0.127244     0.012499         2901          341.0
#
#      Weight
# 0  0.285613
# 1  0.004612
# 2  0.025146
# 3  0.062743
# 4  0.062743

# %%
lib_wt.to_csv('Library_weights.csv', index=False)
